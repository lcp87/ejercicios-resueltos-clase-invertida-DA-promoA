# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Funciones-Universales" data-toc-modified-id="Funciones-Universales-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Funciones Universales</a></span></li><li><span><a href="#Operaciones-estadísticas" data-toc-modified-id="Operaciones-estadísticas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Operaciones estadísticas</a></span><ul class="toc-item"><li><span><a href="#np.mean()" data-toc-modified-id="np.mean()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><code>np.mean()</code></a></span></li><li><span><a href="#np.std():" data-toc-modified-id="np.std():-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><code>np.std()</code>:</a></span></li><li><span><a href="#np.var():" data-toc-modified-id="np.var():-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><code>np.var()</code>:</a></span></li></ul></li><li><span><a href="#Operaciones-aritméticas" data-toc-modified-id="Operaciones-aritméticas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Operaciones aritméticas</a></span><ul class="toc-item"><li><span><a href="#np.min()" data-toc-modified-id="np.min()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><code>np.min()</code></a></span></li><li><span><a href="#np.max()" data-toc-modified-id="np.max()-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><code>np.max()</code></a></span></li><li><span><a href="#np.sum():" data-toc-modified-id="np.sum():-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><code>np.sum()</code>:</a></span></li><li><span><a href="#np.cumsum():" data-toc-modified-id="np.cumsum():-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span><code>np.cumsum()</code>:</a></span></li><li><span><a href="#np.cumprod():" data-toc-modified-id="np.cumprod():-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span><code>np.cumprod()</code>:</a></span></li><li><span><a href="#np.sqtr()-:" data-toc-modified-id="np.sqtr()-:-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span><code>np.sqtr()</code> :</a></span></li><li><span><a href="#np.exp():" data-toc-modified-id="np.exp():-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span><code>np.exp()</code>:</a></span></li><li><span><a href="#np.mod():" data-toc-modified-id="np.mod():-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span><code>np.mod()</code>:</a></span></li></ul></li><li><span><a href="#Operaciones-de-comparación" data-toc-modified-id="Operaciones-de-comparación-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Operaciones de comparación</a></span><ul class="toc-item"><li><span><a href="#np.any()" data-toc-modified-id="np.any()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><code>np.any()</code></a></span></li><li><span><a href="#np.all():" data-toc-modified-id="np.all():-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><code>np.all()</code>:</a></span></li></ul></li><li><span><a href="#Operaciones-trigonométricas" data-toc-modified-id="Operaciones-trigonométricas-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Operaciones trigonométricas</a></span><ul class="toc-item"><li><span><a href="#np.cos():" data-toc-modified-id="np.cos():-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><code>np.cos()</code>:</a></span></li><li><span><a href="#np.sin():" data-toc-modified-id="np.sin():-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><code>np.sin()</code>:</a></span></li><li><span><a href="#np.tan():" data-toc-modified-id="np.tan():-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><code>np.tan()</code>:</a></span></li></ul></li><li><span><a href="#Otras-operaciones" data-toc-modified-id="Otras-operaciones-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Otras operaciones</a></span><ul class="toc-item"><li><span><a href="#np.sort():" data-toc-modified-id="np.sort():-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span><code>np.sort()</code>:</a></span></li><li><span><a href="#np.round():" data-toc-modified-id="np.round():-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span><code>np.round()</code>:</a></span></li><li><span><a href="#np.where():" data-toc-modified-id="np.where():-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span><code>np.where()</code>:</a></span></li></ul></li><li><span><a href="#Nota-sobre-los-ejes-(parámetro-axis)" data-toc-modified-id="Nota-sobre-los-ejes-(parámetro-axis)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Nota sobre los ejes (parámetro <code>axis</code>)</a></span></li></ul></div>

# %% [markdown]
# # Funciones Universales

# %% [markdown]
# Las funciones universales en Numpy son funciones matemáticas simples. NumPy nos va proporcionar varias funciones universales que cubren una amplia variedad de operaciones.
#
#
# Estas funciones incluyen funciones trigonométricas estándar, funciones para operaciones aritméticas, manejo de números complejos, funciones estadísticas, etc.
#
# Las principales carácteristicas de estas funciones son:
#
# - Operan en cualquier tipo de *array* (uni, bi o multidimensional).
#
#
# - Realizan operaciones rápidas.
#
#
# - Numpy, las funciones universales son objetos que pertenecen a la clase numpy.ufunc.
#
#
# - Algunas ufuncs se llaman automáticamente cuando se usa el operador aritmético correspondiente en matrices. Por ejemplo, cuando la suma de dos matrices se realiza por elementos utilizando el operador '+', se llama internamente a np.add(), las cuales vimos en la primera sesión de NumPy
#
#
# A lo largo de esta leccion veremos algunas de ellas:

# %% [markdown]
# 📌 A modo de recordatorio, en la primera sesión vimos algunas de estas funciones, como por ejemplo:
#
# - `add()`: para sumar
#
#
# - `multiply()`: para multiplicar
#
#
# - `substract()`: para restar
#
#
# - `divide()`: para dividir
#
#
#
#
# >🚨⚠️ **PERO RECORDEMOS QUE SI QUERMOS HACER OPERACIONES ENTRE DOS *ARRAYS*  DEBEN TENER LA MISMA FORMA PARA PODER HACER ESTAS OPERACIONES** 🚨⚠️
#
# 🚨 **NOTA** A lo largo de este jupyter trabajaremos con dos *arrays* bidimensionales, pero es igualmente aplicable a cualquier tipo de *array*.

# %%
import numpy as np

# %%
arr1 = np.random.random_sample((3,4))
arr2 = np.random.random_sample((3,4))

# %%
arr1
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
arr2
# Out:
# array([[0.0757229 , 0.85518677, 0.68946746, 0.28829933],
#        [0.02562294, 0.91966368, 0.85136279, 0.58931793],
#        [0.76602808, 0.37331022, 0.43737657, 0.08056663]])

# %% [markdown]
# # Operaciones estadísticas

# %% [markdown]
# ## `np.mean()`
#
# Calcula la media de todos los elementos del *array*.
#
# Este método nos permite elegir el eje sobre el que queremos calcular la media. Para eso tendremos que usar el parámetro `axis`, donde:
#
# - `axis = 0`: nos calculará la media para cada **columna** de nuestro *array*
#
# ![mean.png](attachment:mean.png)

# %% [markdown]
# - `axis = 1`: nos calculará la media para cada **fila** de nuesrto *array*
#
# ![mean_filas.png](attachment:mean_filas.png)
#
#
# Cuando pasamos este parámetro la función `np.mean` produce un nuevo *array* con los resultados.

# %%
# si no especificamos nada nos calculará la media de todos los elementos del array

media = np.mean(arr1)
media
# Out:
# 0.4975438119940024

# %%
# media por columna. Nos va a devolver un valor por cada columna de nuestro array

media_filas = np.mean(arr1, axis = 0)
media_filas
# Out:
# array([0.57256348, 0.42882788, 0.38345766, 0.60532622])

# %%
# media por fila, nos devuelve un valor por cada fila de nuestro array

media_columnas = np.mean(arr1, axis = 1)
media_columnas
# Out:
# array([0.24377514, 0.47205029, 0.77680601])

# %% [markdown]
# ## `np.std()`:
#
# Calcula la desviación estándar en nuestro *array*, por defecto nos lo va a calcular para todos los elementos.
#
# Si le pasamos el parámetro `axis` podemos especificar sobre que eje queremos que nos calcule la desviación estándar.
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas
#
#
# >📌 **NOTA**: La desviación estándar es la medida de dispersión más >común, que indica como de dispersos están los datos con respecto a la >media.
# >
# >Cuanto mayor sea la desviación estándar, mayor será la dispersión de los >datos.

# %%
# desviación estándar de media

np.std(arr1)
# Out:
# 0.31052147981712175

# %%
# ¿ qué pasa con las columnas? 

np.std(arr1, axis = 0)
# Out:
# array([0.26952524, 0.34011307, 0.31535334, 0.25088512])

# %% [markdown]
# Aunque esto lo veremos en más detalle más adelante, intentemos interpretar estos resultados.
#
# Para la primera columna tenemos el siguiente valor: 0.14085392. Esto significa que los valores de la columna 1 se devían 0.14 del valor de la media.

# %%
# ¿y con las filas? 

np.std(arr1, axis = 1)
# Out:
# array([0.13590904, 0.31751475, 0.16415861])

# %% [markdown]
# ## `np.var()`:
#
# Calcula la varianza de los valores de mi *array*. Por defecto lo hará sobre todo el *array*, pero nosotros le podemos especificar el eje usando el parámetro `axis`.
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas
#
#
# >📌 **NOTA**: es una medida de dispersión que representa la variabilidad de una serie de datos respecto a su media. Formalmente se calcula como la suma de los residuos al cuadrado divididos entre el total de observaciones.

# %%
np.var(arr1)
# Out:
# 0.09642358942781516

# %% [markdown]
# # Operaciones aritméticas

# %% [markdown]
# ## `np.min()`
#
# Nos devuelve el valor mínimo de nuestro *array*.
#
# De la misma forma que `np.mean()` nos va a permitir identificar los valores mínimos a través de las columnas o las filas usando el parámetro `axis`.
#
# Igual que en `np.mean()`:
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
minimo = np.min(arr1)
minimo
# Out:
# 0.01298305894698415

# %%
# nos devuelve el valor más pequeño de nuestro array en cada columna

minimo_columnas = np.min(arr1, axis = 0 )
minimo_columnas
# Out:
# array([0.27908408, 0.05536015, 0.01298306, 0.32997261])

# %%
# nos devuelve el valor más pequeño de nuestro array en cada fila

minimo_filas = np.min(arr1, axis = 1 )
minimo_filas
# Out:
# array([0.01298306, 0.05536015, 0.50866567])

# %% [markdown]
# ## `np.max()`
#
# Nos devuelve el valor máximo de nuestro *array*.
#
# Podemos seguir trabajando con el parámetro `axis` para sacar los valores máximos por filas o columnas:
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
maximo = np.max(arr1)
maximo
# Out:
# 0.9367820445299792

# %%
# valor máximo para cada columna

maximo_columnas = np.max(arr1, axis = 0 )
maximo_columnas
# Out:
# array([0.92994069, 0.87806269, 0.78371362, 0.93678204])

# %%
# valor máximo para cada fila
maximo_filas = np.max(arr1, axis = 1 )
maximo_filas
# Out:
# array([0.35306081, 0.92994069, 0.93678204])

# %% [markdown]
# ## `np.sum()`:
#
# Suma los elementos del *array*. Por defecto nos va a sumar todos los elementos del *array* (nos devuelve un único valor). Podemos especificar que nos haga la suma por filas o columnas con el parámetro `axis` (nos devolverá un valor por cada fila o columna que tengamos):
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
arr1
# suma = np.sum(arr1)
# suma
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
suma_columnas = np.sum(arr1, axis = 0)
suma_columnas
# Out:
# array([1.72658313, 1.08314212, 1.40374231, 0.73261061])

# %%
suma_filas = np.sum(arr1, axis = 1)
suma_filas
# Out:
# array([2.05820015, 1.03945809, 1.84841993])

# %% [markdown]
# ## `np.cumsum()`:
#
# Devuelve un *array* con la suma acumulada de los elementos a lo largo nuestro *array*. Por defecto nos lo hará para todo el *array*.

# %%
np.cumsum(arr1)
# Out:
# array([0.27908408, 0.63214489, 0.64512794, 0.97510055, 1.90504124,
#        1.96040139, 2.3140777 , 2.86330172, 3.37196739, 4.25003008,
#        5.0337437 , 5.97052574])

# %% [markdown]
# ¿Qué esta haciendo `np.cumsum`?
#
# - El primer valor del *array* que nos devuelve será igual al primer elemento de nuestro *array* original.
#
#
# - El segundo valor del *array* es la suma del primer elemento del original más el segundo
#
# ```python
#
# ## array original
# array([[0.43158982, 0.42402593, 0.29239649, 0.11322166],
#        [0.62065375, 0.028709  , 0.43423764, 0.60455712],
#        [0.47499132, 0.90050962, 0.54005677, 0.41098125]])
#
# #operación
# np.cumsum(arr1)
#
# #output de cumsum
# array([0.43158982, 0.85561575, 1.14801225, 1.26123391, 1.88188766,
#        1.91059666, 2.3448343 , 2.94939141, 3.42438273, 4.32489235,
#        4.86494912, 5.27593037])
#
#
#
# # el segundo elemento es 0.85561575 que es el resultado de sumar los dos primeros elementos
# 0.43158982 + 0.42402593
#
# ```
# - El tercer valor del *array* resultado de `np.cumsum` es la suma del tercer elemento y el resultado de la suma de los dos anteriores. Y así sucesivamente hasta que se sumen todos los elementos de forma acumulativa.
#
#
# - El último elemento del *array* que nos devuelve será igual que el resultado de hacer la suma de todos los elementos del *array*
#
# Si nos fijamos lo que esta haciendo es coger los dos primeros elementos de nuestro *array* y los suma:

# %% [markdown]
# Al igual que con la suma podemos pasarle el parámetro `axis` para especificar sobre que eje queremos aplicar la operación:
#
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
# para las columnas

np.cumsum(arr1, axis = 0)
# Out:
# array([[0.27908408, 0.35306081, 0.01298306, 0.32997261],
#        [1.20902476, 0.40842096, 0.36665937, 0.87919663],
#        [1.71769044, 1.28648365, 1.15037299, 1.81597867]])

# %%
# para las filas

np.cumsum(arr1, axis = 1)
# Out:
# array([[0.27908408, 0.63214489, 0.64512794, 0.97510055],
#        [0.92994069, 0.98530084, 1.33897714, 1.88820116],
#        [0.50866567, 1.38672836, 2.17044198, 3.10722403]])

# %% [markdown]
# ## `np.cumprod()`:
#
# Devuelve un *array* con la multiplicación acumulada de cada elemento de nuestro *array*. Sigue la misma lógica que el `np.cumsum`.
#
# De la misma forma, por defecto nos lo hará para todo el *array* pero le podemos pasar el parámetro `axis` para definir sobre que eje lo queremos hacer.
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
np.cumprod(arr1)
# Out:
# array([2.79084077e-01, 9.85336500e-02, 1.27926819e-03, 4.22123461e-04,
#        3.92549782e-04, 2.17316151e-05, 7.68595735e-06, 4.22131237e-06,
#        2.14723669e-06, 1.88540842e-06, 1.47762027e-06, 1.38420814e-06])

# %%
# para las columnas

np.cumprod(arr1, axis = 0)
# Out:
# array([[0.27908408, 0.35306081, 0.01298306, 0.32997261],
#        [0.25953164, 0.0195455 , 0.0045918 , 0.18122888],
#        [0.13201483, 0.01716217, 0.00359866, 0.16977196]])

# %%
# para las filas

np.cumprod(arr1, axis = 1)
# Out:
# array([[2.79084077e-01, 9.85336500e-02, 1.27926819e-03, 4.22123461e-04],
#        [9.29940687e-01, 5.14816566e-02, 1.82078422e-02, 1.00001842e-02],
#        [5.08665671e-01, 4.46640347e-01, 3.50038125e-01, 3.27909430e-01]])

# %% [markdown]
# ## `np.sqtr()` :
#
# Calcula la raíz cuadrada no negativa de una matriz, por cada elemento de nuestro *array*.

# %%
raiz = np.sqrt(arr1)
raiz
# Out:
# array([[0.52828409, 0.5941892 , 0.11394323, 0.57443242],
#        [0.96433432, 0.23528738, 0.59470691, 0.7410965 ],
#        [0.71320801, 0.93704999, 0.88527602, 0.96787501]])

# %% [markdown]
# ##  `np.exp()`:
#
# Calcula el exponencial de todos los elementos de la matriz de entrada

# %%
exponencial = np.exp(arr1)
exponencial
# Out:
# array([[2.07060589, 1.55868837, 1.69237257, 1.43387816],
#        [1.75088764, 1.19126972, 1.3138287 , 1.03186716],
#        [1.55056438, 1.59086472, 1.83063945, 1.40615341]])

# %% [markdown]
# ## `np.mod()`:
#
# Calcula el resto de la división entre dos *arrays*.
#
# ¿Recordaís los operadores que vimos al inicio del curso? Pues lo mismo que lo siguiente:
#
# ```python
# variable1 = 23
# variable2 = 45
#
# variable1 % variable2
# ```

# %%
np.mod(arr1, arr2)
# Out:
# array([[0.27908408, 0.02090582, 0.01298306, 0.32997261],
#        [0.0735685 , 0.05536015, 0.35367631, 0.54922402],
#        [0.01524678, 0.30524038, 0.00779313, 0.93678204]])

# %% [markdown]
# # Operaciones de comparación

# %% [markdown]
# ## `np.any()`
#
# Comprueba si **algún** elemento del *array* se evalúa como True dada una condición.
#
# Nos va a devolver un valor booleano (True, False) a no ser que especifiquemos un eje con el parámetro `axis`. En este caso, nos devolverá un valor True o False en función de si se cumple o no la condición.
#
# Recordamos:
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
# vamos a recordar lo que teníamos en el arr1

arr1
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
np.any(arr1)
# Out:
# True

# %%
# como no estamos pasando ningún eje nos devuelve un único valor. 
## si en algún caso se cumple la condición que le pasamos nos devolverá True
### en este caso como tenemos valores en nuestro array mayores que 0.6 nos devolverá True, aunque no sean todos

np.any(arr1 > 0.6)
# Out:
# True

# %%
# ¿se está cumpliendo la condición que pasamos en alguno de los valores
## de cada una de mis columnas? 

np.any(arr1 > 0.6, axis = 0)
# Out:
# array([ True, False,  True, False])

# %% [markdown]
# Entendamos el resultado anterior:
#
# - En nuestra segunda columna tenemos los siguientes valores:
# ```
# [0.72007867, 0.42533541, 0.35549331]
# ```
# ¿ Es **alguno** de estos valores mayor que 0.6? SI. Entonces nos devuelve True
#
#
# - ¿Qué pasa con la tercera columna? Tenemos los siguientes valores:
#
# ```
# [0.06335547, 0.2394793, 0.41744516]
# ```
#
# ¿Es **alguno** de esto valores mayores que 0.6? NO. Entonces nos devuelve False.

# %%
# lo podemos hacer igual con las filas
## en todas las filas de mi array tengo al menos un valor mayor que 0.6, 
### por eso nos devuelve todo True

np.any(arr1, axis = 1)
# Out:
# array([ True,  True,  True])

# %% [markdown]
# ## `np.all()`:
#
# Al contrario que el `np.any()` en este caso comprueba si **todos** los elementos del *array* cumplen la condición que le pasemos.
#
# Recordamos:
#
# - `axis = 0`: columnas
#
#
# - `axis = 1`: filas

# %%
np.all(arr1)
# Out:
# True

# %%
# ¿Son todos los valores de mi array mayores que 0.5? NO
## Por eso nos devuelve False, porque se tiene que cumplir la condición
### en TODOS los elementos de nuestro array

np.all(arr1 > 0.5)
# Out:
# False

# %%
# ¿Son todos los valores de mi array mayores que 0.05? SI!
## Entonces nos devuelve True

np.all(arr1 > 0.05)
# Out:
# False

# %%
# recordemos arr1

arr1
# Out:
# array([[0.27908408, 0.35306081, 0.01298306, 0.32997261],
#        [0.92994069, 0.05536015, 0.35367631, 0.54922402],
#        [0.50866567, 0.87806269, 0.78371362, 0.93678204]])

# %%
# Evaluemos por columnas. 

np.all(arr1 > 0.6, axis = 0)
# Out:
# array([False, False, False, False])

# %% [markdown]
# Entendamos los resultados:
#
# - En la segunda columna tenemos lo siguientes valores:
#
#     ```
#     [0.72007867, 0.42533541, 0.35549331]
#     ```
#      ¿Son **todos** los valores mayores que 0.6? NO. En este caso nos devuelve un False
#
#
#
# - En la primera columna tenemos estos valores:
# ```
# [0.61035226, 0.66440301, 0.93248458]
# ```
# ¿Son **todos** los valores mayores que 0.6? SI. Entonces nos devuelve True

# %% [markdown]
# # Operaciones trigonométricas

# %% [markdown]
# ## `np.cos()`:
#
# Calcula el coseno de cada elemento de nuestro *array*

# %%
np.cos(arr1)
# Out:
# array([[0.74661226, 0.90310738, 0.8647563 , 0.93576192],
#        [0.84718983, 0.9847231 , 0.96298105, 0.999508  ],
#        [0.90533903, 0.89414522, 0.8226924 , 0.94246822]])

# %% [markdown]
# ## `np.sin()`:
#
# Calcula el seno de cada elemento de nuestro *array*

# %%
np.sin(arr1)
# Out:
# array([[0.27547528, 0.34577144, 0.01298269, 0.32401712],
#        [0.80158448, 0.05533188, 0.3463489 , 0.52202553],
#        [0.48701228, 0.76950307, 0.70591463, 0.80565601]])

# %% [markdown]
# ## `np.tan()`:
#
# Calcula la tangente de cada elemento de nuestro *array*

# %%
np.tan(arr1)
# Out:
# array([[0.28656293, 0.36850103, 0.01298379, 0.34249426],
#        [1.34070789, 0.05541678, 0.36920027, 0.61203805],
#        [0.5576082 , 1.20490312, 0.99663658, 1.36002404]])

# %% [markdown]
# # Otras operaciones

# %% [markdown]
# ## `np.sort()`:
#
# Devuelve una copia ordenada de un *array*.
#
# Por defecto nos ordenará por filas de nuestro *array*, si lo que queremos es que nos ordene por columnas tendremos que pasarle el parámetro `axis = 0`.

# %%
arr1
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
np.sort(arr1)
# Out:
# array([[0.36038277, 0.44384468, 0.52613143, 0.72784126],
#        [0.03136994, 0.17501973, 0.27294554, 0.56012288],
#        [0.3408579 , 0.43861898, 0.46427772, 0.60466533]])

# %%
np.sort(arr1, axis = 0)
# Out:
# array([[0.43861898, 0.17501973, 0.27294554, 0.03136994],
#        [0.56012288, 0.44384468, 0.52613143, 0.3408579 ],
#        [0.72784126, 0.46427772, 0.60466533, 0.36038277]])

# %% [markdown]
# ⚠️ Si nos fijamos en cualquiera de los casos nos esta ordenando de menor a mayor.
#
# Pero... ¿Qué pasaría si quisieramos ordenar de mayor a menor?
#
# Le tendríamos que dar la vuelta primero al *array* y luego ordenarlo. ¿Cómo podemos darle la vuelta a un *array*?
#
# > Utilizando el operador `-` delante del *array* y del método

# %%
arr1
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
# con el operador "-"

-np.sort(-arr1)
# Out:
# array([[0.72784126, 0.52613143, 0.44384468, 0.36038277],
#        [0.56012288, 0.27294554, 0.17501973, 0.03136994],
#        [0.60466533, 0.46427772, 0.43861898, 0.3408579 ]])

# %% [markdown]
# ## `np.round()`:
#
# Redondea un *array* al número de decimales especificado.

# %%
np.round(arr1, decimals = 2)
# Out:
# array([[0.28, 0.35, 0.01, 0.33],
#        [0.93, 0.06, 0.35, 0.55],
#        [0.51, 0.88, 0.78, 0.94]])

# %%
np.round(arr1, decimals = 3)
# Out:
# array([[0.279, 0.353, 0.013, 0.33 ],
#        [0.93 , 0.055, 0.354, 0.549],
#        [0.509, 0.878, 0.784, 0.937]])

# %% [markdown]
# 📌 Si nos fijamos, cuando hemos redondeado a tres decimales hay elementos que se han quedado solo con dos decimales. Esto es así porque el tercer decimal es un 0

# %% [markdown]
# ## `np.where()`:
#
# Devuelve elementos en función de la condición dada.
#
# Nos devuelve los **índices** donde encontraremos los valores que cumplan la condición que hemos pasado.

# %%
arr1
# Out:
# array([[0.72784126, 0.44384468, 0.52613143, 0.36038277],
#        [0.56012288, 0.17501973, 0.27294554, 0.03136994],
#        [0.43861898, 0.46427772, 0.60466533, 0.3408579 ]])

# %%
np.where(arr1 > 0.5)
# Out:
# (array([0, 0, 1, 2]), array([0, 2, 0, 2]))

# %% [markdown]
# Interpretemos el *output* que nos da:
#
# ```python
# (array([0, 0, 1, 2]), array([0, 3, 2, 1]))
# ```
#
# - El primero *array* del *output* hace referencia a las filas
#
# ```python
# array([0, 0, 1, 2])
# ```
#
# - El segundo *array* hace refencia a las columnas
#
# ```python
# array([0, 3, 2, 1])
# ```
#
# Entonces ¿qué significa?
#
# - El elemento 0, 0 (fila, columna) cumple la condición
#
#
# - El elemento 0, 3 (fila, columna) cumple la condición
#
#
# - El elemento 1, 2 (fila, columna) cumple la condición
#
#
# Y así sucesivamente, haciendo la combinaciones entre los dos *arrays* que nos devuelve.

# %% [markdown]
# # Nota sobre los ejes (parámetro `axis`)

# %% [markdown]
# En este jupyter hemos hecho todos los ejemplos con un *array* de dos dimensiones. Pero... ¿cómo podríamos acceder a los distintos ejes en un *array* tridimensional?
#
#
# Veamos el siguiente diagrama:
#
# ![ejes-tridimensional.jpeg](https://github.com/Adalab/data_imagenes/blob/main/Modulo-2/NumPy/index-tres-dimensiones.png?raw=true)
#
#
# Si nos fijamos:
#
# - `axis = 0`: hace referencia a la dimensión del *array*
#
#
# - `axis = 1`: hace referencia a las columnas dentro de cada *array*
#
#
# - `axis = 2`: hace referencia a las filas dentro de cada *array*

# %%
# tenemos un array con dos matrices de tres filas y 5 columnas
arr3 = np.random.random_sample((2,3,5))
arr3
# Out:
# array([[[0.08718983, 0.24702588, 0.64428018, 0.23074878, 0.47727007],
#         [0.18060185, 0.66478797, 0.25289929, 0.69510472, 0.60797194],
#         [0.99634582, 0.08357451, 0.78401396, 0.01400455, 0.42529599]],
#
#        [[0.24533743, 0.90730177, 0.46499157, 0.64980924, 0.69565472],
#         [0.66897966, 0.93769283, 0.58202257, 0.79112678, 0.96047726],
#         [0.28176935, 0.09536282, 0.26634058, 0.8653498 , 0.4135761 ]]])

# %%
# hagamos una suma
np.sum(arr3)
# Out:
# 15.21690781134288

# %%
# va a calcularnos la suma para cada matriz que tengamos en nuestro array

np.sum(arr3, axis = 0)
# Out:
# array([[0.33252726, 1.15432765, 1.10927175, 0.88055802, 1.17292479],
#        [0.84958152, 1.60248079, 0.83492186, 1.48623149, 1.5684492 ],
#        [1.27811517, 0.17893733, 1.05035454, 0.87935435, 0.83887209]])

# %%
## hagamos la suma para cada columna
## tendremos 10 resultados, uno por cada columna

np.sum(arr3, axis = 1)
# Out:
# array([[1.26413751, 0.99538835, 1.68119342, 0.93985805, 1.510538  ],
#        [1.19608644, 1.94035741, 1.31335473, 2.30628582, 2.06970808]])

# %%
# hagamos la suma para cada fila
## tendremos 6 resultados. Uno por cada fila que tenemos en nuestro array

np.sum(arr3, axis = 2)
# Out:
# array([[1.68651473, 2.40136577, 2.30323483],
#        [2.96309473, 3.9402991 , 1.92239865]])

# %% [markdown]
# 📌 Para las más curiosas o las que se hayan quedado con ganas de más, dejamos [aquí](https://es.acervolima.com/numpy-ufunc-funciones-universales/) un link con más funciones universales.

# %% [markdown]
# **EJERCICIO 1** En este ejercicio vamos a tratar de usar algunos de los métodos aprendidos.
#
#
#
# - Crea un *array*, puede ser bidimensional o multidimensional! Eso si, los valores tienen que estar entre 0-100
#
# - Calcula:
#
#
#     - La media de los elementos
#
#
#     - La media de las columnas y redondéalo a dos decimales
#
#
#     - El valor máximo de cada fila
#
#
#     - El valor mínimo de cada fila
#
#
#     - Hay algun valor que sea mayor que 90 en tu *array*
#
#
#     - Donde los podemos encontrar, cuáles son sus índices
#
#
#     - Ordena el *array* de mayor a menor
#
# 📝 **NOTA** En este ejercicio os hemos pedido algunos de los métodos, pero sentiros libres de practicar otros para ir asentando los conocimientos.

# %%
# soluciones aquí

array_mult = np.random.randint(0,100,(2,3))
array_mult
# Out:
# array([[25, 29, 81],
#        [96,  3,  2]])

# %%
np.mean(array_mult)
np.round(np.mean(array_mult, axis = 0), decimals= 2)

# %%
np.max(array_mult)
np.min(array_mult)
# Out:
# 57

# %%
np.any(array_mult > 90)
np.where(array_mult)
# Out:
# (array([0, 0, 0, 1, 1, 1]), array([0, 1, 2, 0, 1, 2]))

# %%
# np.sort(array_mult)
-np.sort(-array_mult)
# Out:
# array([[81, 29, 25],
#        [96,  3,  2]])
